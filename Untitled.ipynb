# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
plt.rcParams['figure.figsize'] = 8, 5
plt.style.use("fivethirtyeight")
pd.options.plotting.backend = "plotly"

# %%
data1 = pd.read_csv("/content/drive/MyDrive/datafile (1).csv")
data2 = pd.read_csv("/content/drive/MyDrive/datafile (2).csv")
data3 = pd.read_csv("/content/drive/MyDrive/datafile (3).csv")
data = pd.read_csv("/content/drive/MyDrive/datafile.csv")
production = pd.read_csv("/content/drive/MyDrive/produce.csv")

# %%
df = data.copy()
crops = []
production = []
for i in range(df.shape[0]):
    for _ in range(8):
        crops.append(df['Crop'][i])
    production = production + df.loc[i][1:].tolist()
    
years = df.drop('Crop',axis=1).columns.tolist() * 13

df = pd.DataFrame({'Crop':crops, 'Year': years, 'Production': production})
df = df.dropna().reset_index(drop=True)

fig=px.bar(df,x='Crop', y="Production", animation_frame="Year", 
           animation_group="Crop", color="Crop", hover_name="Crop", range_y=[80,150])
fig.update_layout(title="Production rate of Crops per year")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="3b8249e3-2b1b-486a-81c7-ef20dda45b2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b8249e3-2b1b-486a-81c7-ef20dda45b2f")) {                    Plotly.newPlot(                        "3b8249e3-2b1b-486a-81c7-ef20dda45b2f",                        [{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Rice"],"ids":["Rice"],"legendgroup":"Rice","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Rice","offsetgroup":"Rice","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Rice"],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Wheat"],"ids":["Wheat"],"legendgroup":"Wheat","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Wheat","offsetgroup":"Wheat","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Wheat"],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Coarse Cereals"],"ids":["Coarse Cereals"],"legendgroup":"Coarse Cereals","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Coarse Cereals","offsetgroup":"Coarse Cereals","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Coarse Cereals"],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Pulses"],"ids":["Pulses"],"legendgroup":"Pulses","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Pulses","offsetgroup":"Pulses","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Pulses"],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Vegetables "],"ids":["Vegetables "],"legendgroup":"Vegetables ","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Vegetables ","offsetgroup":"Vegetables ","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Vegetables "],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Fruits"],"ids":["Fruits"],"legendgroup":"Fruits","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Fruits","offsetgroup":"Fruits","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Fruits"],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Milk"],"ids":["Milk"],"legendgroup":"Milk","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Milk","offsetgroup":"Milk","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Milk"],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Crop=%{x}<br>Year=2004-05<br>Production=%{y}<extra></extra>","hovertext":["Eggs, Fish and Meat"],"ids":["Eggs, Fish and Meat"],"legendgroup":"Eggs, Fish and Meat","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Eggs, Fish and Meat","offsetgroup":"Eggs, Fish and Meat","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Eggs, Fish and Meat"],"xaxis":"x","y":[100.0],"yaxis":"y"},{"alignmentgroup":"True","hovertemplate":"<b>%{hovertext}</b><br><br>Cr ...

# %%
df = data1[["State","Cost of Cultivation (`/Hectare) A2+FL"]].copy()
df = df.groupby('State')[["Cost of Cultivation (`/Hectare) A2+FL"]].mean().reset_index()
fig = df.plot(kind='bar',x='State',y="Cost of Cultivation (`/Hectare) A2+FL", color="Cost of Cultivation (`/Hectare) A2+FL")
fig.update_layout(title="State-wise Cost of Cultivation (`/Hectare) A2+FL")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.4.2.min.js"></script>                <div id="3704e56d-59c4-4d82-8f32-6caf7ad80437" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3704e56d-59c4-4d82-8f32-6caf7ad80437")) {                    Plotly.newPlot(                        "3704e56d-59c4-4d82-8f32-6caf7ad80437",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br>Cost of Cultivation (`/Hectare) A2+FL=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[25062.58625,13513.92,19944.2075,22317.120000000003,20025.836,10318.24,24726.826666666664,11480.795,24049.14333333333,11936.632000000001,44421.46,15939.518571428573,24731.06],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["Andhra Pradesh","Bihar","Gujarat","Haryana","Karnataka","Madhya Pradesh","Maharashtra","Orissa","Punjab","Rajasthan","Tamil Nadu","Uttar Pradesh","West Bengal"],"xaxis":"x","y":[25062.58625,13513.92,19944.2075,22317.120000000003,20025.836,10318.24,24726.826666666664,11480.795,24049.14333333333,11936.632000000001,44421.46,15939.518571428573,24731.06],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"Cost of Cultivation (`/Hectare) A2+FL"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...
